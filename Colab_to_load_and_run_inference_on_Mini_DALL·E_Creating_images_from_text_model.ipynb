# %% [markdown]
# <a href="https://colab.research.google.com/github/naashonomics/genai_random/blob/main/Colab_to_load_and_run_inference_on_Mini_DALL%C2%B7E_Creating_images_from_text_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install min-dalle
from min_dalle import MinDalle
import matplotlib.pyplot as plt
import numpy as np
import torch

# loading pre-trained model
model = MinDalle(
    models_root='./pretrained',
    dtype=torch.float32,
    device='cuda',
    is_mega=True,
    is_reusable=True
)
# Out:
# Collecting min-dalle
#   Using cached min-dalle-0.4.11.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.10/dist-packages (from min-dalle) (2.1.0+cu121)
# Requirement already satisfied: typing_extensions>=4.1 in /usr/local/lib/python3.10/dist-packages (from min-dalle) (4.9.0)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.10/dist-packages (from min-dalle) (1.25.2)
# Requirement already satisfied: pillow>=7.1 in /usr/local/lib/python3.10/dist-packages (from min-dalle) (9.4.0)
# Requirement already satisfied: requests>=2.23 in /usr/local/lib/python3.10/dist-packages (from min-dalle) (2.31.0)
# Collecting emoji (from min-dalle)
#   Downloading emoji-2.10.1-py2.py3-none-any.whl (421 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.5/421.5 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23->min-dalle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23->min-dalle) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23->min-dalle) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23->min-dalle) (2024.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->min-dalle) (3.13.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->min-dalle) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->min-dalle) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->min-dalle) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->min-dalle) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->min-dalle) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11->min-dalle) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11->min-dalle) (1.3.0)
# Building wheels for collected packages: min-dalle
#   Building wheel for min-dalle (setup.py) ... done
#   Created wheel for min-dalle: filename=min_dalle-0.4.11-py3-none-any.whl size=10518 sha256=cd47868b87eacdab98d91e5372cbef7fe3f1985f4f2a042dd5c365de35b21729
#   Stored in directory: /root/.cache/pip/wheels/52/6d/e3/c4eae4ec07f23168d03ed0f58073be84cd4d0a4c990eec7dc2
# Successfully built min-dalle
# Installing collected packages: emoji, min-dalle
# Successfully installed emoji-2.10.1 min-dalle-0.4.11
# using device cuda
# downloading tokenizer params
# intializing TextTokenizer
# downloading encoder params
# initializing DalleBartEncoder
# downloading decoder params
# initializing DalleBartDecoder
# downloading detokenizer params
# initializing VQGanDetokenizer

# %%
# @title String fields
text_input = 'flying batman with colorful sky' # @param {type:"string"}
# e.g. 'flying animals with blue sky and white clouds'

# %% [markdown]
# Text2Image

# %%
plt.figure(figsize=(10,5))
max_images = 5
for x in range(max_images):
  image = model.generate_image(
      text=text_input,
      seed=-1,
      grid_size=1
  )
  image = np.asarray(image)
  plt.subplot(1,5,x+1); plt.imshow(image); plt.axis('off')
  print(x+1,'/',max_images,' --- generated')
plt.suptitle(text_input)
plt.tight_layout()
# Out:
# 1 / 5  --- generated
# 2 / 5  --- generated
# 3 / 5  --- generated
# 4 / 5  --- generated
# 5 / 5  --- generated
